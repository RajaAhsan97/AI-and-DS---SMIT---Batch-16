# %% [markdown]
# ## Python Class 2 - print() Function
#
# print() - It is a builtin function of Python
#         - It will print any value given to it
#         - It can print any number of values comma seprated
#
# ### Value - Data
# Value can be any thing
#   - number
#         - whole numbers - e.g, 0, 1, 2 ,4: integer
#         - decimal numbers - e.g. 2.5, 10.1: float

# %%
print()

# %%
print(5.7)
# Out:
# 5.7

# %%
print(1,3,5,6)
# Out:
# 1 3 5 6

# %%
print(1,3,5,6,sep='-')
# Out:
# 1-3-5-6
