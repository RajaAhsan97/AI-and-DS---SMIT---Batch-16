# %% [markdown]
# # Data Structures : Collection

# %%
name = "Anas"

# %% [markdown]
# ## What is collection?
# When we store more than 1 value to a single variable

# %% [markdown]
# 1. List
# 2. Tuple
# 3. Dictionary
# 4. Set
# 5. String

# %% [markdown]
# # LIST

# %% [markdown]
# - [] --> to create list
# - It is mutable
# - List is iterable

# %%
# empty list
names = []

# %%
type(names)
# Out:
# list

# %%
# length
len(names)
# Out:
# 0

# %%
# List with elements
elements = ["AHsan", 2, 3.4, True]

# %%
elements
# Out:
# ['AHsan', 2, 3.4, True]

# %%
len(elements)
# Out:
# 4

# %%
names = ["Hassan", "Mohsin", "SHameer", "Talha", "Saad", "Ammar"]

# %%
len(names)
# Out:
# 6

# %% [markdown]
# ## Index or Indices

# %%
# +ve        0         1         2        3         4      5
names = ["Hassan", "Mohsin", "SHameer", "Talha", "Saad", "Ammar"]
# -ve       -6         -5        -4       -3        -2     -1

# %% [markdown]
# # Access elements using index number
#
# - []

# %% [markdown]
# names[-3]

# %%
names[2], names[-4]
# Out:
# ('SHameer', 'SHameer')

# %%
# Indexing: 1 waqt mein 1 elements 

# SLicing: access subset of list (1 waqt mein multiple elements)

# %%
# +ve        0         1         2        3         4      5
names = ["Hassan", "Mohsin", "SHameer", "Talha", "Saad", "Ammar"]
# -ve       -6         -5        -4       -3        -2     -1

# %%
# slicing
names[1:4]
# Out:
# ['Mohsin', 'SHameer', 'Talha']

# %%
names[::]
# Out:
# ['Hassan', 'Mohsin', 'SHameer', 'Talha', 'Saad', 'Ammar']

# %%
names[-5:-2]
# Out:
# ['Mohsin', 'SHameer', 'Talha']

# %%
# +ve        0         1         2        3         4      5
names = ["Hassan", "Mohsin", "SHameer", "Talha", "Saad", "Ammar"]
# -ve       -6         -5        -4       -3        -2     -1

# %%
names[1:]   # or names[1:6]
# Out:
# ['Mohsin', 'SHameer', 'Talha', 'Saad', 'Ammar']

# %%
names[-6:-2]
# Out:
# ['Hassan', 'Mohsin', 'SHameer', 'Talha']

# %%
names[-6:4]
# Out:
# ['Hassan', 'Mohsin', 'SHameer', 'Talha']

# %%
names[3:-3]
# Out:
# []

# %%
names[2:-3]
# Out:
# ['SHameer']

# %%
names[1:7:1]  # start, end, step
# Out:
# ['Mohsin', 'SHameer', 'Talha', 'Saad', 'Ammar']

# %%
# +ve        0         1         2        3         4      5
names = ["Hassan", "Mohsin", "SHameer", "Talha", "Saad", "Ammar"]
# -ve       -6         -5        -4       -3        -2     -1

# %%
names[1:7:2]
# Out:
# ['Mohsin', 'Talha', 'Ammar']

# %%
names[::6]
# Out:
# ['Hassan']

# %%
names[::-1]
# Out:
# ['Ammar', 'Saad', 'Talha', 'SHameer', 'Mohsin', 'Hassan']

# %%
# +ve        0         1         2        3         4      5
names = ["Hassan", "Mohsin", "SHameer", "Talha", "Saad", "Ammar"]
# -ve       -6         -5        -4       -3        -2     -1

# %%
names[4:1:-1]
# Out:
# ['Saad', 'Talha', 'SHameer']

# %% [markdown]
# # List Functions

# %% [markdown]
# ### Adding elements in List
#
# - insert()  ---> given poistion insert element
# - append()  --> adds an element in last
# - extend()  --> adds another collection one by one
# -  +        --> two list  ko join krawata h

# %%
names
# Out:
# ['Hassan', 'Mohsin', 'SHameer', 'Talha', 'Saad', 'Ammar']

# %%
names.append("Ubaid")

# %%
names
# Out:
# ['Hassan', 'Mohsin', 'SHameer', 'Talha', 'Saad', 'Ammar', 'Ubaid']

# %%
names.insert(4, "Hasnain")

# %%
names
# Out:
# ['Hassan', 'Mohsin', 'SHameer', 'Talha', 'Hasnain', 'Saad', 'Ammar', 'Ubaid']

# %%
new_names = ["ahmed", "ALi", "AHsan"]

#names.extend(new_names)

# %%
names
# Out:
# ['Hassan',
#  'Mohsin',
#  'SHameer',
#  'Talha',
#  'Hasnain',
#  'Saad',
#  'Ammar',
#  'Ubaid',
#  'ahmed',
#  'ALi',
#  'AHsan']
