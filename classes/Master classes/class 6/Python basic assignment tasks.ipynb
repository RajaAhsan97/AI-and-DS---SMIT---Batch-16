# %% [markdown]
# # String COncatenation

# %% [markdown]
# ### Q.11

# %%
first_name = "Raja"
last_name = "Ahsan"

first_name + " " + last_name
# Out:
# 'Raja Ahsan'

# %% [markdown]
# ### Q.12

# %%
first_name = "raja"
last_name = "ahsan"

last_name + "." + first_name + "@" + "example.com"
# Out:
# 'ahsan.raja@example.com'

# %% [markdown]
# # String Repitition

# %% [markdown]
# ### Q.14

# %%
character = input("Enter character:")

character * 10
# Out:
# Enter character: *
# '**********'

# %% [markdown]
# # Comparison Operator

# %% [markdown]
# ### Q20

# %% [markdown]
# age = 10
#
# age_checker = age >= 18
#
# print(age_checker)

# %% [markdown]
# ### Q22

# %%
age = 20
have_license = True

eligibility = age >= 18 and have_license

print(eligibility)
# Out:
# True

# %% [markdown]
# # Membership Operator

# %% [markdown]
# ### Q.27

# %%
email = "ahsanraja@gmail.com"

"@" in email
# Out:
# True
