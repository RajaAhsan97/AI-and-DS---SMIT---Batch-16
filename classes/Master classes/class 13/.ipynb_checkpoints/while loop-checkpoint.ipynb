# %% [markdown]
# # While loop:
#     - jb humein loop ki iteration pata nai hoti ky loop ko kitni baar chalana h. Bulky loop ko kisi condition py khatam ho to hum while loop istamal krty hein

# %%
while True:
    print("Mein loop m hun...")
