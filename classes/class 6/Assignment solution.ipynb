# %% [markdown]
# # Arithmetic operator

# %%
# Q17:

radius = float(input("Enter radius"))

area = 3.14 * radius ** 2
circumference = 2 * 3.14 * radius

print(f"Area: {area}")
print(f"Circum: {circumference}")
# Out:
# Enter radius 5
# Area: 78.5
# Circum: 31.400000000000002

# %%
# Q1

name = "Hassan"
age = 11
course = "AI and DS"
institute = "SMIT"

print(f"""
Name: {name}
Age: {age}
Course: {course}
Institute: {institute}
""")
# Out:
# Name: Hassan
# Age: 11
# Course: AI and DS
# Institute: SMIT

# %%
# Q19

unit_price = 50
quantity = 10

total_price = unit_price * quantity

# total_price 10%    [total_price * 10/100]
discount = total_price * 0.10  # discount

final_price = total_price - discount

print(f"Total price: {total_price}")
print(f"Discount: {discount}")
print(f"final Price: {final_price}")
# Out:
# Total price: 500
# Discount: 50.0
# final Price: 450.0

# %%
# Q.22

age = 15
has_license = True

age >= 18 and has_license
# Out:
# False

# %%
# Q 27

email = "ahsanraja@gmail.com"

"@" in email
# Out:
# True

# %%
# Q24

purchaseamount = 6000
ismember = True

purchaseamount >= 5000 or ismember
# Out:
# True
