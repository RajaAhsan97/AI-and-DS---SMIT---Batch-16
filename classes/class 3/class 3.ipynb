# %% [markdown]
# - Value - Data
#       - number
#           - whole numbers : integers
#           - decimal numbers: float
#       - text
#           - string --> 'Ahsan' or "Ahsan" or '''Ahsan''' or """Ahsan"""
#       - Boolean
#           - True or False

# %%
print('This is my 3 rd class')
# Out:
# This is my 3 rd class

# %%
print("This is my 3 rd class")
# Out:
# This is my 3 rd class

# %%
print("This is my 3 rd class Welcome")
# Out:
# This is my 3 rd class Welcome

# %%
print('''This is my 3rd class 
Welcome to AI and DS course''')
# Out:
# This is my 3rd class
# Welcome to AI and DS course

# %%
print("""This is my 3rd class 
Welcome to AI and DS course""")
# Out:
# This is my 3rd class
# Welcome to AI and DS course

# %%
print("Hello I am Raja Ahsan", "and I teaching AI")
# Out:
# Hello I am Raja Ahsan and I teaching AI

# %%
print("Raja AHsan", end=" ")
print("COmputer Vision Engineer")
# Out:
# Raja AHsan COmputer Vision Engineer

# %%
print("AI and DS", "Python", "ML", sep="\n")
# Out:
# AI and DS
# Python
# ML

# %%
print("AI and DS", "Python", "ML", sep="\t")
# Out:
# AI and DS	Python	ML

# %% [markdown]
# # Operators in Python

# %% [markdown]
# 1. Arithmetic Operators
# 2. Comparison Operators
# 3. Logical operators
# 4. Membership operators
# 5. Identity operators
# 6. Bitwise operators

# %% [markdown]
# # Arithmetic operators
#
# +, -, *, /, //, **, %

# %%
2 + 3
# Out:
# 5

# %%
7/2
# Out:
# 3.5

# %%
# floor division
7//2
# Out:
# 3

# %%
# modulus operator %
7%2
# Out:
# 1

# %%
# exponentiation
2 ** 5
# Out:
# 32

# %% [markdown]
# Arithmetic operators on string data

# %%
# concatination operation
"Raja" + " " + "Ahsan"
# Out:
# 'Raja Ahsan'

# %%
# Repetition operation
"Ahsna" * 5
# Out:
# 'AhsnaAhsnaAhsnaAhsnaAhsna'

# %% [markdown]
# ## COmparison Operator
#
# 1. == --> equals to
# 2. != --> not equals to
# 3. >
# 4. <
# 5. >=
# 6. <=

# %%
5 == 6
# Out:
# False

# %%
5 >= 6
# Out:
# False

# %%
15 < 18 < 25
# Out:
# True

# %% [markdown]
# # Comparison Operators on String data

# %%
"cat" == "cat"
# Out:
# True

# %%
ord('C')
# Out:
# 67

# %%
"cat" != "Cat"
# Out:
# True

# %%
'apple' > 'banana'
# Out:
# False
