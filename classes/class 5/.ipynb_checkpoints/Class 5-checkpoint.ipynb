# %%
number = 3  

# range 5 and 10
# True      and     True 
in_range = number >= 5 and number <= 10

print(in_range)
# Out:
# False

# %% [markdown]
# # input() function

# %%
value = input("Enter number:")
# Out:
# Enter number: 8

# %%
print(value)
# Out:
# 8

# %% [markdown]
# # type() function in Python

# %%
type(value)
# Out:
# str

# %% [markdown]
# # type conversion in Python

# %%
x = input("Enter number:") # 8
x = int(x)

type(x)
# Out:
# Enter number: 8
# int

# %%
x = float(input("Enter a number:"))

print(type(x))
print(x)
# Out:
# Enter a number: 8
# <class 'float'>
# 8.0

# %%
x = 5.7

print(int(x))
# Out:
# 5

# %% [markdown]
# # f-string

# %%
value = 8

# formatted string
print(f'The value is {value}')
# Out:
# The value is 8

# %%
name_ = input("Enter your name")
experience = float(input("Enter experience"))
course_ = input("Enter your course")

print(f"""
NAMe: {name_}
experience: {experience} years
Course: {course_}
""")
# Out:
# Enter your name Ahsan
# Enter experience 78
# Enter your course AI and DS
# NAMe: Ahsan
# experience: 78.0 years
# Course: AI and DS
