# %%
# +ve          0        1         2         3        4         5         6         7        
students = ["Ahsan", "Talha", "Hammad", "Hassan", "Javaid", "Amjad", "Sheryar", "Yahya"]
# -ve         -8       -7        -6         -5       -4        -3        -2        -1

# %%
# sort --> tarteeb dena
students.sort()

# %%
students
# Out:
# ['Ahsan', 'Amjad', 'Hammad', 'Hassan', 'Javaid', 'Sheryar', 'Talha', 'Yahya']

# %%
# descending order
students.sort(reverse=True)

# %%
students
# Out:
# ['Yahya', 'Talha', 'Sheryar', 'Javaid', 'Hassan', 'Hammad', 'Amjad', 'Ahsan']

# %%
numbers = [49,50,67,0, 1]

# %%
numbers.sort()

# %%
numbers
# Out:
# [0, 1, 49, 50, 67]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [67, 50, 49, 1, 0]

# %%
students
# Out:
# ['Yahya', 'Talha', 'Sheryar', 'Javaid', 'Hassan', 'Hammad', 'Amjad', 'Ahsan']

# %%
students.append(0)

# %%
students
# Out:
# ['Yahya',
#  'Talha',
#  'Sheryar',
#  'Javaid',
#  'Hassan',
#  'Hammad',
#  'Amjad',
#  'Ahsan',
#  0]

# %%
del students[-1]

# %%
students
# Out:
# ['Yahya', 'Talha', 'Sheryar', 'Javaid', 'Hassan', 'Hammad', 'Amjad', 'Ahsan']

# %%
students.reverse()

# %%
students
# Out:
# ['Ahsan', 'Amjad', 'Hammad', 'Hassan', 'Javaid', 'Sheryar', 'Talha', 'Yahya']

# %%
students.index("Amjad")
# Out:
# 1

# %%
students.count("Amjad")
# Out:
# 1

# %% [markdown]
# ### DELETE a member from List

# %%
students
# Out:
# ['Ahsan', 'Amjad', 'Hammad', 'Hassan', 'Javaid', 'Sheryar', 'Talha', 'Yahya']

# %% [markdown]
# - del:   delete by index
# - pop():  delete by index
# - remove(): delete by value
# - clear(): delete all elements

# %%
students
# Out:
# ['Ahsan', 'Amjad', 'Hammad', 'Hassan', 'Javaid', 'Sheryar', 'Talha', 'Yahya']

# %%
del students[1]

# %%
students
# Out:
# ['Ahsan', 'Hammad', 'Hassan', 'Javaid', 'Sheryar', 'Talha', 'Yahya']

# %%
students.remove("Ahsan")

# %%
students
# Out:
# ['Hammad', 'Hassan', 'Javaid', 'Sheryar', 'Talha', 'Yahya']

# %%
students.pop()
# Out:
# 'Yahya'

# %%
students.pop(0)
# Out:
# 'Hammad'

# %%
students.clear()

# %%
students
# Out:
# []

# %% [markdown]
# # Dictionary

# %% [markdown]
# - {}
# - data {key:value}
# - no indexing
# - mutable

# %%
records = {"Name":"Ahsan", "Course": "AI and DS", "Batch": 16}

# %%
print(type(records))
# Out:
# <class 'dict'>

# %%
len(records)
# Out:
# 3

# %%
# Adding a value to dictionary

records["Name"]
# Out:
# 'Ahsan'

# %%
records["Course"]
# Out:
# 'AI and DS'

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS', 'Batch': 16}

# %%
records["Campus"] ="Hajiyani Sakeena"

# %%
records
# Out:
# {'Name': 'Ahsan',
#  'Course': 'AI and DS',
#  'Batch': 16,
#  'Campus': 'Hajiyani Sakeena'}

# %%
records["Campus"] = "ZAIT"

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS', 'Batch': 16, 'Campus': 'ZAIT'}

# %%
records["Batch"]
# Out:
# 16

# %%
del records["Campus"]

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS', 'Batch': 16}

# %%
records.pop("Batch")
# Out:
# 16

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS'}

# %%
records.popitem()
# Out:
# ('Course', 'AI and DS')

# %%
records
# Out:
# {'Name': 'Ahsan'}

# %%
records["Course"] = "AI and DS"
records["Batch"] = 16

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS', 'Batch': 16}

# %%
records.keys()
# Out:
# dict_keys(['Name', 'Course', 'Batch'])

# %%
records.values()
# Out:
# dict_values(['Ahsan', 'AI and DS', 16])

# %%
records.items()
# Out:
# dict_items([('Name', 'Ahsan'), ('Course', 'AI and DS'), ('Batch', 16)])

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS', 'Batch': 16}

# %%
records.get("Course")
# Out:
# 'AI and DS'

# %%
records["Course"]
# Out:
# 'AI and DS'

# %%
records["Campus"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 records["Campus"]
#
# KeyError: 'Campus'

# %%
records.get("Semester", "Key not found")
# Out:
# 'Key not found'

# %%
meta_data = {"Semester": 2, "Location": "New Town"}

# %%
records
# Out:
# {'Name': 'Ahsan', 'Course': 'AI and DS', 'Batch': 16}

# %%
records.update(meta_data)

# %%
records
# Out:
# {'Name': 'Ahsan',
#  'Course': 'AI and DS',
#  'Batch': 16,
#  'Semester': 2,
#  'Location': 'New Town'}
