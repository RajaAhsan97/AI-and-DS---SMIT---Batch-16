# %% [markdown]
# # Logical operator

# %% [markdown]
# 1. and
# 2. or
# 3. not

# %% [markdown]
# False and False  ---> False
# False and True   ---> False
# True and False   ---> False
# True and True    ---> True

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and True
# Out:
# True

# %%
age = 19
# True    and   True  
age >= 17 and age <= 20
# Out:
# True

# %% [markdown]
# # Or operator

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %% [markdown]
# # not operator

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # Membership Operator

# %%
"AH" in "AHSAN"
# Out:
# True

# %%
3 in [1,2,3,4,5]
# Out:
# True

# %%
2 not in [1,2,3,4,5]
# Out:
# False

# %% [markdown]
# # Variable

# %%
x = 9

# %%
x = 10

# %%
x = x +  1  # 9+1 = 10

print(x)
# Out:
# 11

# %% [markdown]
# 1. Must start with letter or underscore  for e.g. student or _student
# 2. student9
# 3. student_name

# %%
name = "Shameer"
course = "AI and DS"
batch = 16

print("Name:", name, "\nCourse: ",course,"\nBatch:",batch)
# Out:
# Name: Shameer
# Course:  AI and DS
# Batch: 16

# %% [markdown]
# # Operators Precedence aand Associativity

# %%
husnain = 10 /2 + 3 * 2 ** 3 - (6//2 + 1) * 3 % 4

print(husnain)
# Out:
# 29.0
